# %%
import clickhouse_connect
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# --- 1. Connect to ClickHouse ---
client = clickhouse_connect.get_client(
    host='192.168.88.253',  # change as needed
    port=8123,
    username='default',  # or your username
    password='uf80Zfvt7XWORQtn',     
)

# %%
query = """
SELECT
    toTimezone(dt, 'Europe/Moscow') AS dt,
    container,
    event,
    data
FROM raw.rl_snake_logs
PREWHERE (deploy_dt = (
    SELECT max(deploy_dt)
    FROM raw.rl_snake_logs
)) AND match(container, 'inf') AND match(event, 'state_received')
ORDER BY dt DESC
limit 1000

"""

df = client.query_df(query)


df
# Out:
#                                      dt  container           event  \
# 0      2025-09-06 13:28:30.131853+03:00  inference  state_received
# 1      2025-09-06 13:28:30.120780+03:00  inference  state_received
# 2      2025-09-06 13:28:30.109793+03:00  inference  state_received
# 3      2025-09-06 13:28:30.098836+03:00  inference  state_received
# 4      2025-09-06 13:28:30.087881+03:00  inference  state_received
# ...                                 ...        ...             ...
# 528572 2025-09-06 11:28:47.036206+03:00  inference  state_received
# 528573 2025-09-06 11:28:47.016237+03:00  inference  state_received
# 528574 2025-09-06 11:28:46.995720+03:00  inference  state_received
# 528575 2025-09-06 11:28:46.963825+03:00  inference  state_received
# 528576 2025-09-06 11:28:46.944238+03:00  inference  state_received
#
#                                                      data
# 0       {'delay_s': '0.0004546642303466797', 'episode'...
# 1       {'delay_s': '0.0004756450653076172', 'episode'...
# 2       {'delay_s': '0.0004398822784423828', 'episode'...
# 3       {'delay_s': '0.0004405975341796875', 'episode'...
# 4       {'delay_s': '0.00044083595275878906', 'episode...
# ...                                                   ...
# 528572  {'delay_s': '0.00036787986755371094', 'episode...
# 528573  {'delay_s': '0.002031564712524414', 'episode':...
# 528574  {'delay_s': '0.010637760162353516', 'episode':...
# 528575  {'delay_s': '0.001306295394897461', 'episode':...
# 528576  {'delay_s': '0.014298439025878906', 'episode':...
#
# [528577 rows x 4 columns]

# %%
states = df['data'].to_list()

# %%
states[0]
# Out:
# {'delay_s': '0.0004546642303466797',
#  'episode': np.int64(558),
#  'frame': np.int64(2039),
#  'function': 'neural_agent_local',
#  'game_over': np.True_,
#  'line': np.int64(176),
#  'logger_name': 'root',
#  'module': 'main',
#  'reward': np.float64(0.0),
#  'visible_cells': {'0,5': 'EMPTY',
#   '1,4': 'EMPTY',
#   '1,5': 'EMPTY',
#   '1,6': 'EMPTY',
#   '10,5': 'EMPTY',
#   '2,3': 'EMPTY',
#   '2,4': 'EMPTY',
#   '2,5': 'EMPTY',
#   '2,6': 'EMPTY',
#   '2,7': 'EMPTY',
#   '3,2': 'EMPTY',
#   '3,3': 'EMPTY',
#   '3,4': 'EMPTY',
#   '3,5': 'EMPTY',
#   '3,6': 'EMPTY',
#   '3,7': 'EMPTY',
#   '3,8': 'EMPTY',
#   '4,1': 'EMPTY',
#   '4,2': 'EMPTY',
#   '4,3': 'EMPTY',
#   '4,4': 'EMPTY',
#   '4,5': 'EMPTY',
#   '4,6': 'EMPTY',
#   '4,7': 'EMPTY',
#   '4,8': 'EMPTY',
#   '4,9': 'EMPTY',
#   '5,0': 'BODY',
#   '5,1': 'EMPTY',
#   '5,10': 'BODY',
#   '5,2': 'EMPTY',
#   '5,3': 'EMPTY',
#   '5,4': 'EMPTY',
#   '5,5': 'HEAD',
#   '5,6': 'BODY',
#   '5,7': 'BODY',
#   '5,8': 'BODY',
#   '5,9': 'BODY',
#   '6,1': 'EMPTY',
#   '6,2': 'EMPTY',
#   '6,3': 'EMPTY',
#   '6,4': 'EMPTY',
#   '6,5': 'EMPTY',
#   '6,6': 'EMPTY',
#   '6,7': 'EMPTY',
#   '6,8': 'EMPTY',
#   '6,9': 'EMPTY',
#   '7,2': 'EMPTY',
#   '7,3': 'EMPTY',
#   '7,4': 'EMPTY',
#   '7,5': 'EMPTY',
#   '7,6': 'EMPTY',
#   '7,7': 'EMPTY',
#   '7,8': 'EMPTY',
#   '8,3': 'EMPTY',
#   '8,4': 'EMPTY',
#   '8,5': 'EMPTY',
#   '8,6': 'EMPTY',
#   '8,7': 'EMPTY',
#   '9,4': 'EMPTY',
#   '9,5': 'EMPTY',
#   '9,6': 'EMPTY'}}

# %%
# %run ../docs/state_visualizer.py

# From list of states (your log storage)
#states = [{'visible_cells': {...}, 'reward': 0.1, 'episode': 1, 'frame': 42}, ...]
#visualizer = SnakeStateVisualizer(states[:1000])
#anim = visualizer.animate()

# From JSON file
#visualizer = SnakeStateVisualizer.from_file('experiment_states.json')
#anim = visualizer.animate()

# Or use convenience functions
#anim = visualize_states(states, interval=200)
#anim = visualize_from_file('states.json', interval=200)
# Out:
# Usage: python state_visualizer.py <states_file.json> [interval_ms]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
visualizer = SnakeStateVisualizer(states[:1000])

# %%
visualizer.show_frame(0)
